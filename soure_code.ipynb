# %%
import numpy as np

# %%
import cv2

# %%
import dlib

# %%
from deepface import DeepFace
from math import hypot

# %%
cap=cv2.VideoCapture("video.mp4")
frame_width=int(cap.get(3))
frame_height=int(cap.get(4))
size=(frame_width,frame_height)
#cap=cv2.VideoCapture(0)
#ose_image = cv2.imread("pig_nose.png")
nose_image4=cv2.imread("nose4.jpg")
nose_image5=cv2.imread("nose5.jpg")
nose_image6=cv2.imread("nose6.jpg")
nose_image7=cv2.imread("nose7.jpg")
nose_image8=cv2.imread("nose8.jpg")
spects=cv2.imread("spects.jpg")
spects1=cv2.imread("spects2.jpg")
spects2=cv2.imread("spects3.jpg")
spects3=cv2.imread("spects1.jpg")
tie_image=cv2.imread("bow_tie.jpg")
emoji=cv2.imread("neutral_emoji.jpg")
emoji1=cv2.imread("happy_emoji.png")
emoji2=cv2.imread("sad_emoji.jpg")
emoji3=cv2.imread("surprice_emoji.jpg")
emoji4=cv2.imread("anger_emoji.jpg")
bindi=cv2.imread("bindi.jpg")
req,framew=cap.read()
rows, cols, _ = framew.shape
nose_mask = np.zeros((rows, cols), np.uint8)
tie_mask=np.zeros((rows, cols), np.uint8)
emo_mask=np.zeros((rows, cols), np.uint8)
emo_mask1=np.zeros((rows, cols), np.uint8)
emo_mask2=np.zeros((rows, cols), np.uint8)
emo_mask3=np.zeros((rows, cols), np.uint8)
emo_mask4=np.zeros((rows, cols), np.uint8)
flower_mask=np.zeros((rows, cols), np.uint8)
results=cv2.VideoWriter('video_output.mp4',cv2.VideoWriter_fourcc(*'MJPG'),10,size)

spects_mask=np.zeros((rows, cols), np.uint8)
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
while True:
    ret,frame=cap.read()
    result=DeepFace.analyze(frame,actions=['emotion'],enforce_detection=False)
    res=result['dominant_emotion']
    cv2.putText(frame,result['dominant_emotion']+" "+str(result['emotion'][result['dominant_emotion']]),(50,50),cv2.FONT_HERSHEY_SIMPLEX,3,(0,0,255),2,cv2.LINE_4)
    nose_mask.fill(0)
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = detector(frame)
    for face in faces:
        landmarks = predictor(gray_frame, face)
    
#     #for nose
#     top_nose = (landmarks.part(29).x, landmarks.part(29).y)
#     center_nose = (landmarks.part(30).x, landmarks.part(30).y+3)
#     left_nose = (landmarks.part(31).x, landmarks.part(31).y)
#     right_nose = (landmarks.part(35).x, landmarks.part(35).y)
#     nose_width = int(hypot(left_nose[0] - right_nose[0],
#                        left_nose[1] - right_nose[1]) * 1.2)
#     nose_height = int(nose_width * 1)
#     top_left = (int(center_nose[0] - nose_width / 2),
#                           int(center_nose[1] - nose_height / 2))
#     bottom_right = (int(center_nose[0] + nose_width / 2),
#                    int(center_nose[1] + nose_height / 2))   
#     nose_pig = cv2.resize(nose_image, (nose_width, nose_height),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
#     nose_pig_gray = cv2.cvtColor(nose_pig, cv2.COLOR_BGR2GRAY)
#     _, nose_mask = cv2.threshold(nose_pig_gray,25, 255, cv2.THRESH_BINARY_INV)
#     nose_area = frame[top_left[1]: top_left[1] + nose_height,
#                 top_left[0]: top_left[0] + nose_width]
#     nose_area_no_nose = cv2.bitwise_and(nose_area, nose_area, mask=nose_mask)
#     final_nose = cv2.add(nose_area_no_nose, nose_pig)
#     frame[top_left[1]: top_left[1] + nose_height,
#                 top_left[0]: top_left[0] + nose_width] = final_nose
    
#     #for bindi
#     left_tie = (landmarks.part(39).x, landmarks.part(39).y)
#     right_tie = (landmarks.part(42).x, landmarks.part(42).y)
#     center_noses = (landmarks.part(27).x, (landmarks.part(27).y)*0.98)
#     tie_width = int(hypot(left_tie[0] - right_tie[0],
#                        left_tie[1] - right_tie[1]) *0.5)
#     tie_height = int(nose_width *0.35)
#     top_lefts = (int((center_noses[0] - tie_width / 2)),
#                           int(center_noses[1] - tie_height / 2))
    
#     tie_png = cv2.resize(bindi, (tie_width, tie_height),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
#     tie_png_gray = cv2.cvtColor(tie_png, cv2.COLOR_BGR2GRAY)
#     _, tie_mask = cv2.threshold(tie_png_gray,25, 255, cv2.THRESH_BINARY_INV)
#     tie_area = frame[top_lefts[1]: top_lefts[1] + tie_height,
#                 top_lefts[0]: top_lefts[0] + tie_width]
#     no_tie = cv2.bitwise_and(tie_area, tie_area, mask=tie_mask)
#     final_tie = cv2.add(no_tie, tie_png)
#     frame[top_lefts[1]: top_lefts[1] + tie_height,
#                 top_lefts[0]: top_lefts[0] + tie_width] = final_tie
    
    
    
    #for emoji
    if result['dominant_emotion']=='neutral':
        top_emo = (landmarks.part(62).x, landmarks.part(62).y)
        center_emo = (landmarks.part(66).x, landmarks.part(66).y)
        left_emo= (landmarks.part(67).x, landmarks.part(67).y)
        right_emo = (landmarks.part(65).x, landmarks.part(65).y)
        emo_width = int(hypot(left_emo[0] - right_emo[0],
                           left_emo[1] - right_emo[1]) *2)
        emo_height = int(emo_width * 1)
        top_left2 = (int(center_emo[0] - emo_width / 2),
                              int(center_emo[1] - emo_height / 2))
        emo_png= cv2.resize(emoji, (emo_width, emo_height),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        emo_gray = cv2.cvtColor(emo_png, cv2.COLOR_BGR2GRAY)
        _, emo_mask = cv2.threshold(emo_gray,25, 255, cv2.THRESH_BINARY_INV)
        emo_area = frame[top_left2[1]: top_left2[1] + emo_height,
                    top_left2[0]: top_left2[0] + emo_width]
        no_emo = cv2.bitwise_and(emo_area, emo_area, mask=emo_mask)
        final_emo1 = cv2.add(no_emo, emo_png)
        frame[top_left2[1]: top_left2[1] + emo_height,
                    top_left2[0]: top_left2[0] + emo_width] = final_emo1
        #FOR SCEPTS
        top_eye = (landmarks.part(38).x, landmarks.part(38).y)
        center_eye = (landmarks.part(27).x, landmarks.part(27).y+5)
        left_eye= (landmarks.part(36).x, landmarks.part(36).y)
        right_eye = (landmarks.part(45).x, landmarks.part(45).y)
        eye_width = int(hypot(left_eye[0] - right_eye[0],
                           left_eye[1] - right_eye[1]) * 1.5)
        eye_height = int(eye_width * 0.87)
        top_left1 = (int(center_eye[0] - eye_width / 2),
                              int(center_eye[1] - eye_height / 2)) 
        eye_png= cv2.resize(spects1, (eye_width, eye_height),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        eye_gray = cv2.cvtColor(eye_png, cv2.COLOR_BGR2GRAY)
        _, eye_mask = cv2.threshold(eye_gray,25, 255, cv2.THRESH_BINARY_INV)
        eye_area = frame[top_left1[1]: top_left1[1] + eye_height,
                    top_left1[0]: top_left1[0] + eye_width]
        no_eye = cv2.bitwise_and(eye_area, eye_area, mask=eye_mask)
        final_eye = cv2.add(no_eye, eye_png)
        frame[top_left1[1]: top_left1[1] + eye_height,
                    top_left1[0]: top_left1[0] + eye_width] = final_eye
        #for nose
        top_nose = (landmarks.part(29).x, landmarks.part(29).y)
        center_nose = (landmarks.part(30).x, landmarks.part(30).y+3)
        left_nose = (landmarks.part(31).x, landmarks.part(31).y)
        right_nose = (landmarks.part(35).x, landmarks.part(35).y)
        nose_width = int(hypot(left_nose[0] - right_nose[0],
                           left_nose[1] - right_nose[1]) * 1.2)
        nose_height = int(nose_width * 1)
        top_left = (int(center_nose[0] - nose_width / 2),
                              int(center_nose[1] - nose_height / 2))
        bottom_right = (int(center_nose[0] + nose_width / 2),
                       int(center_nose[1] + nose_height / 2))   
        nose_pig = cv2.resize(nose_image4, (nose_width, nose_height),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        nose_pig_gray = cv2.cvtColor(nose_pig, cv2.COLOR_BGR2GRAY)
        _, nose_mask = cv2.threshold(nose_pig_gray,25, 255, cv2.THRESH_BINARY_INV)
        nose_area = frame[top_left[1]: top_left[1] + nose_height,
                    top_left[0]: top_left[0] + nose_width]
        nose_area_no_nose = cv2.bitwise_and(nose_area, nose_area, mask=nose_mask)
        final_nose = cv2.add(nose_area_no_nose, nose_pig)
        frame[top_left[1]: top_left[1] + nose_height,
                    top_left[0]: top_left[0] + nose_width] = final_nose
    
    elif result['dominant_emotion']=='happy':
        top_emo1 = (landmarks.part(62).x, landmarks.part(62).y)
        center_emo1 = (landmarks.part(66).x, landmarks.part(66).y)
        left_emo1= (landmarks.part(67).x, landmarks.part(67).y)
        right_emo1 = (landmarks.part(65).x, landmarks.part(65).y)
        emo_width1 = int(hypot(left_emo1[0] - right_emo1[0],
                           left_emo1[1] - right_emo1[1]) * 3)
        emo_height1 = int(emo_width1 * 1)
        top_left3 = (int(center_emo1[0] - emo_width1 / 2),
                              int(center_emo1[1] - emo_height1 / 2))
        emo_png1= cv2.resize(emoji1, (emo_width1, emo_height1),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        emo_gray1 = cv2.cvtColor(emo_png1, cv2.COLOR_BGR2GRAY)
        _, emo_mask1 = cv2.threshold(emo_gray1,25, 255, cv2.THRESH_BINARY_INV)
        emo_area1 = frame[top_left3[1]: top_left3[1] + emo_height1,
                    top_left3[0]: top_left3[0] + emo_width1]
        no_emo1 = cv2.bitwise_and(emo_area1, emo_area1, mask=emo_mask1)
        final_emo2 = cv2.add(no_emo1, emo_png1)
        frame[top_left3[1]: top_left3[1] + emo_height1,
                    top_left3[0]: top_left3[0] + emo_width1] = final_emo2 
        #FOR SCEPTS
        top_eye = (landmarks.part(38).x, landmarks.part(38).y)
        center_eye = (landmarks.part(27).x, landmarks.part(27).y+5)
        left_eye= (landmarks.part(36).x, landmarks.part(36).y)
        right_eye = (landmarks.part(45).x, landmarks.part(45).y)
        eye_width = int(hypot(left_eye[0] - right_eye[0],
                           left_eye[1] - right_eye[1]) * 1.5)
        eye_height = int(eye_width * 0.75)
        top_left1 = (int(center_eye[0] - eye_width / 2),
                              int(center_eye[1] - eye_height / 2)) 
        eye_png= cv2.resize(spects2, (eye_width, eye_height),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        eye_gray = cv2.cvtColor(eye_png, cv2.COLOR_BGR2GRAY)
        _, eye_mask = cv2.threshold(eye_gray,25, 255, cv2.THRESH_BINARY_INV)
        eye_area = frame[top_left1[1]: top_left1[1] + eye_height,
                    top_left1[0]: top_left1[0] + eye_width]
        no_eye = cv2.bitwise_and(eye_area, eye_area, mask=eye_mask)
        final_eye = cv2.add(no_eye, eye_png)
        frame[top_left1[1]: top_left1[1] + eye_height,
                    top_left1[0]: top_left1[0] + eye_width] = final_eye  
        #for nose
        top_nose = (landmarks.part(29).x, landmarks.part(29).y)
        center_nose = (landmarks.part(30).x, landmarks.part(30).y+3)
        left_nose = (landmarks.part(31).x, landmarks.part(31).y)
        right_nose = (landmarks.part(35).x, landmarks.part(35).y)
        nose_width = int(hypot(left_nose[0] - right_nose[0],
                           left_nose[1] - right_nose[1]) * 1.2)
        nose_height = int(nose_width * 1)
        top_left = (int(center_nose[0] - nose_width / 2),
                              int(center_nose[1] - nose_height / 2))
        bottom_right = (int(center_nose[0] + nose_width / 2),
                       int(center_nose[1] + nose_height / 2))   
        nose_pig = cv2.resize(nose_image8, (nose_width, nose_height),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        nose_pig_gray = cv2.cvtColor(nose_pig, cv2.COLOR_BGR2GRAY)
        _, nose_mask = cv2.threshold(nose_pig_gray,25, 255, cv2.THRESH_BINARY_INV)
        nose_area = frame[top_left[1]: top_left[1] + nose_height,
                    top_left[0]: top_left[0] + nose_width]
        nose_area_no_nose = cv2.bitwise_and(nose_area, nose_area, mask=nose_mask)
        final_nose = cv2.add(nose_area_no_nose, nose_pig)
        frame[top_left[1]: top_left[1] + nose_height,
                    top_left[0]: top_left[0] + nose_width] = final_nose

    
    elif result['dominant_emotion']=='sad':
        top_emo2 = (landmarks.part(62).x, landmarks.part(62).y)
        center_emo2 = (landmarks.part(66).x, landmarks.part(66).y)
        left_emo2= (landmarks.part(67).x, landmarks.part(67).y)
        right_emo2 = (landmarks.part(65).x, landmarks.part(65).y)
        emo_width2 = int(hypot(left_emo2[0] - right_emo2[0],
                           left_emo2[1] - right_emo2[1]) * 3)
        emo_height2 = int(emo_width2 * 1)
        top_left4 = (int(center_emo2[0] - emo_width2 / 2),
                              int(center_emo2[1] - emo_height2 / 2))
        emo_png2= cv2.resize(emoji2, (emo_width2, emo_height2),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        emo_gray2 = cv2.cvtColor(emo_png2, cv2.COLOR_BGR2GRAY)
        _, emo_mask2 = cv2.threshold(emo_gray2,25, 255, cv2.THRESH_BINARY_INV)
        emo_area2 = frame[top_left4[1]: top_left4[1] + emo_height2,
                    top_left4[0]: top_left4[0] + emo_width2]
        no_emo2 = cv2.bitwise_and(emo_area2, emo_area2, mask=emo_mask2)
        final_emo3 = cv2.add(no_emo2, emo_png2)
        frame[top_left4[1]: top_left4[1] + emo_height2,
                    top_left4[0]: top_left4[0] + emo_width2] = final_emo3 
        #FOR SCEPTS
        top_eye = (landmarks.part(38).x, landmarks.part(38).y)
        center_eye = (landmarks.part(27).x, landmarks.part(27).y+5)
        left_eye= (landmarks.part(36).x, landmarks.part(36).y)
        right_eye = (landmarks.part(45).x, landmarks.part(45).y)
        eye_width = int(hypot(left_eye[0] - right_eye[0],
                           left_eye[1] - right_eye[1]) * 1.5)
        eye_height = int(eye_width * 0.81)
        top_left1 = (int(center_eye[0] - eye_width / 2),
                              int(center_eye[1] - eye_height / 2)) 
        eye_png= cv2.resize(spects3, (eye_width, eye_height),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        eye_gray = cv2.cvtColor(eye_png, cv2.COLOR_BGR2GRAY)
        _, eye_mask = cv2.threshold(eye_gray,25, 255, cv2.THRESH_BINARY_INV)
        eye_area = frame[top_left1[1]: top_left1[1] + eye_height,
                    top_left1[0]: top_left1[0] + eye_width]
        no_eye = cv2.bitwise_and(eye_area, eye_area, mask=eye_mask)
        final_eye = cv2.add(no_eye, eye_png)
        frame[top_left1[1]: top_left1[1] + eye_height,
                    top_left1[0]: top_left1[0] + eye_width] = final_eye  
        #for nose
        top_nose = (landmarks.part(29).x, landmarks.part(29).y)
        center_nose = (landmarks.part(30).x, landmarks.part(30).y+3)
        left_nose = (landmarks.part(31).x, landmarks.part(31).y)
        right_nose = (landmarks.part(35).x, landmarks.part(35).y)
        nose_width = int(hypot(left_nose[0] - right_nose[0],
                           left_nose[1] - right_nose[1]) * 1.2)
        nose_height = int(nose_width * 1)
        top_left = (int(center_nose[0] - nose_width / 2),
                              int(center_nose[1] - nose_height / 2))
        bottom_right = (int(center_nose[0] + nose_width / 2),
                       int(center_nose[1] + nose_height / 2))   
        nose_pig = cv2.resize(nose_image6, (nose_width, nose_height),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        nose_pig_gray = cv2.cvtColor(nose_pig, cv2.COLOR_BGR2GRAY)
        _, nose_mask = cv2.threshold(nose_pig_gray,25, 255, cv2.THRESH_BINARY_INV)
        nose_area = frame[top_left[1]: top_left[1] + nose_height,
                    top_left[0]: top_left[0] + nose_width]
        nose_area_no_nose = cv2.bitwise_and(nose_area, nose_area, mask=nose_mask)
        final_nose = cv2.add(nose_area_no_nose, nose_pig)
        frame[top_left[1]: top_left[1] + nose_height,
                    top_left[0]: top_left[0] + nose_width] = final_nose
    elif result['dominant_emotion']=='anger':
        top_emo3 = (landmarks.part(62).x, landmarks.part(62).y)
        center_emo3 = (landmarks.part(66).x, landmarks.part(66).y)
        left_emo3= (landmarks.part(67).x, landmarks.part(67).y)
        right_emo3 = (landmarks.part(65).x, landmarks.part(65).y)
        emo_width3 = int(hypot(left_emo3[0] - right_emo3[0],
                           left_emo3[1] - right_emo3[1]) * 3)
        emo_height3 = int(emo_width3 * 1)
        top_left5 = (int(center_emo3[0] - emo_width3 / 2),
                              int(center_emo3[1] - emo_height3 / 2))
        emo_png3= cv2.resize(emoji4, (emo_width3, emo_height3),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        emo_gray3 = cv2.cvtColor(emo_png3, cv2.COLOR_BGR2GRAY)
        _, emo_mask4 = cv2.threshold(emo_gray3,25, 255, cv2.THRESH_BINARY_INV)
        emo_area3 = frame[top_left5[1]: top_left5[1] + emo_height3,
                    top_left5[0]: top_left5[0] + emo_width3]
        no_emo3 = cv2.bitwise_and(emo_area3, emo_area3, mask=emo_mask4)
        final_emo4 = cv2.add(no_emo3, emo_png3)
        frame[top_left5[1]: top_left5[1] + emo_height3,
                    top_left5[0]: top_left5[0] + emo_width3] = final_emo4 
        #FOR SCEPTS
        top_eye = (landmarks.part(38).x, landmarks.part(38).y)
        center_eye = (landmarks.part(27).x, landmarks.part(27).y+5)
        left_eye= (landmarks.part(36).x, landmarks.part(36).y)
        right_eye = (landmarks.part(45).x, landmarks.part(45).y)
        eye_width = int(hypot(left_eye[0] - right_eye[0],
                           left_eye[1] - right_eye[1]) * 1.5)
        eye_height = int(eye_width * 0.77)
        top_left1 = (int(center_eye[0] - eye_width / 2),
                              int(center_eye[1] - eye_height / 2)) 
        eye_png= cv2.resize(spects, (eye_width, eye_height),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        eye_gray = cv2.cvtColor(eye_png, cv2.COLOR_BGR2GRAY)
        _, eye_mask = cv2.threshold(eye_gray,25, 255, cv2.THRESH_BINARY_INV)
        eye_area = frame[top_left1[1]: top_left1[1] + eye_height,
                    top_left1[0]: top_left1[0] + eye_width]
        no_eye = cv2.bitwise_and(eye_area, eye_area, mask=eye_mask)
        final_eye = cv2.add(no_eye, eye_png)
        frame[top_left1[1]: top_left1[1] + eye_height,
                    top_left1[0]: top_left1[0] + eye_width] = final_eye 
        #for nose
        top_nose = (landmarks.part(29).x, landmarks.part(29).y)
        center_nose = (landmarks.part(30).x, landmarks.part(30).y+3)
        left_nose = (landmarks.part(31).x, landmarks.part(31).y)
        right_nose = (landmarks.part(35).x, landmarks.part(35).y)
        nose_width = int(hypot(left_nose[0] - right_nose[0],
                           left_nose[1] - right_nose[1]) * 1.2)
        nose_height = int(nose_width * 1)
        top_left = (int(center_nose[0] - nose_width / 2),
                              int(center_nose[1] - nose_height / 2))
        bottom_right = (int(center_nose[0] + nose_width / 2),
                       int(center_nose[1] + nose_height / 2))   
        nose_pig = cv2.resize(nose_image5, (nose_width, nose_height),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        nose_pig_gray = cv2.cvtColor(nose_pig, cv2.COLOR_BGR2GRAY)
        _, nose_mask = cv2.threshold(nose_pig_gray,25, 255, cv2.THRESH_BINARY_INV)
        nose_area = frame[top_left[1]: top_left[1] + nose_height,
                    top_left[0]: top_left[0] + nose_width]
        nose_area_no_nose = cv2.bitwise_and(nose_area, nose_area, mask=nose_mask)
        final_nose = cv2.add(nose_area_no_nose, nose_pig)
        frame[top_left[1]: top_left[1] + nose_height,
                    top_left[0]: top_left[0] + nose_width] = final_nose
    else:
        top_emo4 = (landmarks.part(62).x, landmarks.part(62).y)
        center_emo4 = (landmarks.part(66).x, landmarks.part(66).y)
        left_emo4= (landmarks.part(67).x, landmarks.part(67).y)
        right_emo4 = (landmarks.part(65).x, landmarks.part(65).y)
        emo_width4 = int(hypot(left_emo4[0] - right_emo4[0],
                           left_emo4[1] - right_emo4[1]) * 3)
        emo_height4 = int(emo_width4 * 1)
        top_left6 = (int(center_emo4[0] - emo_width4 / 2),
                              int(center_emo4[1] - emo_height4 / 2))
        emo_png4= cv2.resize(emoji3, (emo_width4, emo_height4),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        emo_gray4 = cv2.cvtColor(emo_png4, cv2.COLOR_BGR2GRAY)
        _, emo_mask3 = cv2.threshold(emo_gray4,25, 255, cv2.THRESH_BINARY_INV)
        emo_area4 = frame[top_left6[1]: top_left6[1] + emo_height4,
                    top_left6[0]: top_left6[0] + emo_width4]
        no_emo4 = cv2.bitwise_and(emo_area4, emo_area4, mask=emo_mask3)
        final_emo5 = cv2.add(no_emo4, emo_png4)
        frame[top_left6[1]: top_left6[1] + emo_height4,
                    top_left6[0]: top_left6[0] + emo_width4] = final_emo5
        #FOR SCEPTS
        top_eye = (landmarks.part(38).x, landmarks.part(38).y)
        center_eye = (landmarks.part(27).x, landmarks.part(27).y+5)
        left_eye= (landmarks.part(36).x, landmarks.part(36).y)
        right_eye = (landmarks.part(45).x, landmarks.part(45).y)
        eye_width = int(hypot(left_eye[0] - right_eye[0],
                           left_eye[1] - right_eye[1]) * 1.5)
        eye_height = int(eye_width * 0.75)
        top_left1 = (int(center_eye[0] - eye_width / 2),
                              int(center_eye[1] - eye_height / 2)) 
        eye_png= cv2.resize(spects2, (eye_width, eye_height),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        eye_gray = cv2.cvtColor(eye_png, cv2.COLOR_BGR2GRAY)
        _, eye_mask = cv2.threshold(eye_gray,25, 255, cv2.THRESH_BINARY_INV)
        eye_area = frame[top_left1[1]: top_left1[1] + eye_height,
                    top_left1[0]: top_left1[0] + eye_width]
        no_eye = cv2.bitwise_and(eye_area, eye_area, mask=eye_mask)
        final_eye = cv2.add(no_eye, eye_png)
        frame[top_left1[1]: top_left1[1] + eye_height,
                    top_left1[0]: top_left1[0] + eye_width] = final_eye  
        #for nose
        top_nose = (landmarks.part(29).x, landmarks.part(29).y)
        center_nose = (landmarks.part(30).x, landmarks.part(30).y+3)
        left_nose = (landmarks.part(31).x, landmarks.part(31).y)
        right_nose = (landmarks.part(35).x, landmarks.part(35).y)
        nose_width = int(hypot(left_nose[0] - right_nose[0],
                           left_nose[1] - right_nose[1]) * 1.2)
        nose_height = int(nose_width * 1)
        top_left = (int(center_nose[0] - nose_width / 2),
                              int(center_nose[1] - nose_height / 2))
        bottom_right = (int(center_nose[0] + nose_width / 2),
                       int(center_nose[1] + nose_height / 2))   
        nose_pig = cv2.resize(nose_image7, (nose_width, nose_height),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        nose_pig_gray = cv2.cvtColor(nose_pig, cv2.COLOR_BGR2GRAY)
        _, nose_mask = cv2.threshold(nose_pig_gray,25, 255, cv2.THRESH_BINARY_INV)
        nose_area = frame[top_left[1]: top_left[1] + nose_height,
                    top_left[0]: top_left[0] + nose_width]
        nose_area_no_nose = cv2.bitwise_and(nose_area, nose_area, mask=nose_mask)
        final_nose = cv2.add(nose_area_no_nose, nose_pig)
        frame[top_left[1]: top_left[1] + nose_height,
                    top_left[0]: top_left[0] + nose_width] = final_nose
    
    cv2.imshow("frame",frame)
    results.write(frame)
    key = cv2.waitKey(10)
    if key == 27:
        break
cap.release()
results.release()
cv2.destroyAllWindows()
